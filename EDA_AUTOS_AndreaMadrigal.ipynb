# %% [markdown]
# <img SRC="carro.jpg"/>

# %% [markdown]
# <center><h1 Style="color:#00FFFF"> Analisis de datos <hi></center>
# <center><h5>Universidad Castro Carazo<h5></center>
# <center><h6>3C-2022 <h6></center>
#     </br>
#     <p Style = "text-align: justify">Este notebook contiene el analisis de los datos de los vehiculos a la venta por parte de la empresa Pk2, esta empresa se encuentra interesada en responder una pregunta de negocio particular.
#
# Como se puede incrementar las ventas de autos de segunda mano?
#
# Para esto se realiza un analisis del conjunto de datos facilitado por la empresa a efectos de poder brindar conocimiento sobre las ditribuciones de sus lotes de venta, los autos con mayor precio, o caracteristicas de los autos, esto para dotar de insumos suficientes a la toma de desiciones.</p>
#    </br>
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile">Fuente de Datos para el proceso de analisis </a>
#
# <h2 Style="color:#1E90FF">1. Carga y estandarizacion de los set de datos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Importar las librerias de necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los ecabezados de los DataFrames</li>
#     <li>Si solo Si temenos mas de 1 set de datos - Unir los set de datos en un unico Dataframe</li>
# </ol>
#
# <h3 Style="color:#2F4F4F">1.1 Importar las librerias</h3>

# %%
import pandas as pd       #Se usa para el manejo de los DataFrame
import numpy as np        #Se usa para el manejo de las estructuras de datos (Array, Listas, Tuplas, Diccionarios)
import matplotlib.pyplot as plt #Se usa para crear las graficas.

# %% [markdown]
#  <h2 Style="color:#1E90FF">1.2 Importar set de datos</h2>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]

df_1er_autos = pd.read_csv("autos.csv", names=cols)
df_2do_autos = pd.read_csv("Autos 1.csv",names=cols)

# %%
df_1er_autos.shape
# Out:
# (197, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
df_1er_autos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# ...

# %%
df_2do_autos.tail(5)
# Out:
#     symboling normalized        make    fuel aspiration doors  style wheels  \
# 24          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 25          0          ?  volkswagen     gas        std  four  wagon    fwd
# 26         -2        103       volvo     gas        std  four  sedan    rwd
# 27         -1         74       volvo     gas        std  four  wagon    rwd
# 28         -2        103       volvo     gas        std  four  sedan    rwd
#
#    engine   base  ...  engine-size  system  bore  stroke compression  \
# 24  front  100.4  ...           97     idi  3.01    3.40        23.0
# 25  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 26  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 27  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 28  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak City  Higway  price
# 24         68  4500   33      38  13845
# ...

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %% [markdown]
# <h5 Style= "color:#DC143C">  1.3 Revisar los encabezados de los DataFrame <h5>
# <p> Se motiva la estandarizacion de los nombres de las columnas, considerando lo siguiente </p>
# <ol>
# <li> Los nombres de las columnas no deben contener espacions en blanco</li>
# <li>Los nombres no deben empezar por numeros</li>
# <li>Si el nombre se conforma por dos o mas palabras la letra inicial de cada palabra va en mayuscula</li>
# <li>No deben existir nombres repetidos</li>
# </ol>

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_autos.rename({'engine-size': 'engineSize'}, axis=1, inplace=True)
df_2do_autos.rename({'engine-size': 'engineSize'}, axis=1, inplace=True)
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# df_2do_autos.columns

# %% [markdown]
# <h5 Style= "color:#DC143C"> 1.4 Revision de variables<h5>
# <p>Este proceso de revision permite identificar variables o datos que deben ser analizados de manera independiente, porque no concuerdan con la metadata
# </p>

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engineSize  compression        City      Higway
# count   197.000000  197.000000   197.000000  197.000000  197.000000
# mean   2534.796954  126.263959    10.128020   25.416244   30.984772
# std     520.401159   42.282594     3.934467    6.566717    6.908644
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# ...

# %%
df_1er_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engineSize   197 non-null    int64
#  17  system       197 non-null    object
# ...

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
temp = df_1er_autos.groupby(["style"]).count()
temp = temp.iloc[:,:1]
temp
# Out:
#              symboling
# style
# convertible          6
# hardtop              8
# hatchback           70
# sedan               90
# wagon               23

# %% [markdown]
# <h5 Style= "color:#DC143C"> 1.5 Unir sets de datos<h5>

# %%
unionArchivos = [df_1er_autos, df_2do_autos]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.shape
# Out:
# (226, 26)

# %% [markdown]
# <h2 style='color:#4B008'> 2. Manejo de los valores faltantes o perdidos </h2>
#
#
#
# <p>Que se hace en este apartado?</p>
#
#
#
# <ol>
#     <li>Identificar como se muestran los valores faltantes y los estandarizamos (NaN)</li>
#     <li>Contar la cantidad de valores faltantes por varible</li>
#     <li>Analisis de imputacion de valores numeros con la media</li>
#     <li>Analisis de imputacion de valores categoricos con el mas frecuente</li>
#     <li>Eliminar filas con valores faltantes</li>
# </ol>
#
#
#
# <h2 style='color:#80008'> 2.1 Identificar como se muestran los valores faltantes y los estandarizamos (NaN) </h2>

# %%
dfAutos.replace("?",np.nan,inplace= True)
dfAutos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2        NaN         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1        NaN         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0        NaN         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...         130    mpfi  3.47    2.68         9.0
# ...

# %% [markdown]
# <h2 style='color:#4B008'> 2.2 Contar la cantidad de valores faltantes por varible

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
# 3   False  False  ...       False   False  False   False        False
# 4   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# ...

# %%
for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engineSize
# False    226
# Name: engineSize, dtype: int64
#
# system
# ...

# %% [markdown]
# <h2 style='color:#4B008'>2.3 Analisis de imputacion de valores numericos
# <img src="valoresfaltantes.png" alt="Valores Perdidos">

# %%
mean_normalized = dfAutos["normalized"].astype("float").mean(axis=0) #obteniendo la media de la variable
print("La media de la normalidad es: ", mean_normalized )
# Out:
# La media de la normalidad es:  122.28333333333333

# %%
dfAutos["normalized"].replace(np.nan, 122, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
mean_value = dfAutos["bore"].astype("float").mean(axis=0)
print ("La media es: ", mean_value)
# Out:
# La media es:  3.319459459459461

# %%
dfAutos["peak"].replace(np.nan, 3, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 style='color:#4B008'> 2.4 Analisis de Imputacion de valores categoricos con el mas frecuente <h2>

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 style='color:#4B008'> 2.5 Eliminar filas con valores faltantes <h2>

# %%
dfAutos.dropna(subset = ["price"], axis = 0, inplace = True)
dfAutos.reset_index(drop= True, inplace = True)

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# Cylinders
# False    222
# Name: Cylinders, dtype: int64
#
# engineSize
# False    222
# Name: engineSize, dtype: int64
#
# system
# False    222
# ...

# %% [markdown]
# <h2 style='color:#06c4d8'> 3 Estandarizacion de los Datos </h2>

# %% [markdown]
# <p> Que se hace en este apartado? </p>
#
#
#
# <ol>
#     <li>Se verifica el dominio de la variable y se ajusta, si es necesario</li>
#     <li>Se convierten los valores en función de su interpretación </li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1</li>
#     <li>Binning</li>
# </ol>
#
#
#
# <h3 style="color: #B22222">3.1 Verificacion del dominio de variables</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
dfAutos[["normalize"]]= dfAutos[["normalized"]]. astype("int")
dfAutos[["bore","stroke", "peak", "horsepower","price"]]= dfAutos[["bore","stroke", "peak", "horsepower","price"]]. astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower     float64
# peak           float64
# City             int64
# Higway           int64
# price          float64
# normalize        int32
# dtype: object

# %% [markdown]
# <h3 style="color: #B22222">3.2 Estandarizacion de Valores</h3>

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  system  bore  stroke  compression horsepower  \
# 0    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0      111.0
# 1    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0      111.0
# 2    rwd  front  94.5  ...    mpfi  2.68    3.47          9.0      154.0
#
#      peak  City Higway    price  normalize
# 0  5000.0    21     27  13495.0        122
# 1  5000.0    21     27  16500.0        122
# 2  5000.0    19     26  16500.0        122
#
# [3 rows x 27 columns]

# %%
dfAutos["city 1L/100km"]= 235/dfAutos["City"]
dfAutos["Higway 1L/100km"]= 235/dfAutos["Higway"]
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  stroke  compression  horsepower    peak City  \
# 0    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
# 1    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
# 2    rwd  front  94.5  ...    3.47          9.0       154.0  5000.0   19
#
#   Higway    price normalize  city 1L/100km  Higway 1L/100km
# 0     27  13495.0       122      11.190476         8.703704
# 1     27  16500.0       122      11.190476         8.703704
# 2     26  16500.0       122      12.368421         9.038462
#
# [3 rows x 29 columns]

# %% [markdown]
# <h3 style="color: #B22222">3.3 Normalizacion de Valores</h3>

# %%
dfTemp= dfAutos[["length", "width", "heingt"]]
dfTemp.head(5) #para comparar valores entre si, para que nos de un valor entre 0 y 1
# Out:
#    length  width  heingt
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
dfAutos["length"]= dfAutos["length"]/dfAutos["length"].max()
dfAutos["width"]= dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingt"]= dfAutos["heingt"]/dfAutos["heingt"].max()

# %%
dfTemp2 = dfAutos[["length", "width", "heingt"]] #siempre es mejor crear nuevas columnas
dfTemp2.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# <h3 style="color: #B22222">3.4 Binning</h3> #crear valores a partir de los datos

# %%
dfTemp = dfAutos["horsepower"]
dfTemp.head(10)
# Out:
# 0    111.0
# 1    111.0
# 2    154.0
# 3    102.0
# 4    115.0
# 5    110.0
# 6    110.0
# 7    110.0
# 8    140.0
# 9    101.0
# Name: horsepower, dtype: float64

# %%
dfAutos.dtypes
# Out:
# symboling            int64
# normalized          object
# make                object
# fuel                object
# aspiration          object
# doors               object
# style               object
# wheels              object
# engine              object
# base               float64
# length             float64
# width              float64
# heingt             float64
# curb                 int64
# engineType          object
# Cylinders           object
# engineSize           int64
# system              object
# bore               float64
# stroke             float64
# compression        float64
# horsepower         float64
# peak               float64
# City                 int64
# Higway               int64
# price              float64
# normalize            int32
# city 1L/100km      float64
# Higway 1L/100km    float64
# dtype: object

# %%
bins = np.linspace(min(dfAutos["horsepower"]), max(dfAutos["horsepower"]),4)
bins
#comando que divide lo que esta en esta columna en 4 datos especificos
#Agrupar los datos
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupnames = ["bajo", "medio", "alto"]
dfAutos["horsepowerBins"] = pd.cut(dfAutos["horsepower"],bins,labels=groupnames, include_lowest=True) 
dfAutos[["horsepower","horsepowerBins"]].head(5)
# Out:
#    horsepower horsepowerBins
# 0       111.0           bajo
# 1       111.0           bajo
# 2       154.0          medio
# 3       102.0           bajo
# 4       115.0           bajo

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot



plt.pyplot.hist(dfAutos["horsepower"])



plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot



plt.pyplot.hist(dfAutos["horsepower"])



plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %% [markdown]
# dfAutos.head(2)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_colors = ['#000000', '#4c3c35', '#636784', '#786a58']

ax.bar(fruits, counts, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')


plt.show()

# %%
#Se agrupan los datos por categoria
gf1= dfAutos.groupby(["horsepowerBins"]).count()
#Se extrae el indice y la primera columna con datos
gf1= gf1.iloc[:,:1]
gf1
# Out:
#                 symboling
# horsepowerBins
# bajo                  172
# medio                  43
# alto                    5

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

eje_x = ['bajo', 'medio', 'alto']
eje_y = gf1["symboling"].tolist()
bar_colors = ['#786a58', '#786a58', '#636784']

ax.bar(eje_x, eje_y, color=bar_colors)

ax.set_ylabel('Cantidad HP')
ax.set_title('Autos agrupados segun HP')


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
#Se agrupan los datos por categoria
gf2= dfAutos.groupby(["make"]).count()
#Se extrae el indice y la primera columna con datos
gf2= gf2.iloc[:,:1]
gf2
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                4
# renault                2
# saab                   6
# subaru                12
# toyota                46
# volkswagen            24
# volvo                  6

# %%
fig, ax = plt.subplots()
eje_x = gf2.index.tolist()
eje_y = gf2["symboling"].tolist()

y_pos = np.arange(len(eje_x))
bar_colors = ['#786a58', '#786a58', '#786a58', '#786a58', '#786a58', '#786a58', '#786a58','#786a58', '#786a58','#786a58', '#786a58','#786a58', '#786a58','#786a58', '#786a58','#786a58', '#786a58','#786a58', '#786a58',  '#636784']

ax.barh(y_pos, eje_y, align='center', color= bar_colors)
ax.set_yticks(y_pos, labels=eje_x)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('Cantidad de Autos segun marca')

plt.show()

# %%
#Se agrupan los datos por categoria
gf3= dfAutos.groupby(["doors"]).count()
#Se extrae el indice y la primera columna con datos
gf3= gf3.iloc[:,:1]
gf3
# Out:
#        symboling
# doors
# four         125
# two           97

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

eje_x = ['four', 'two']
eje_y = gf3["symboling"].tolist()
bar_colors = ['#786a58', '#636784']

ax.bar(eje_x, eje_y, color=bar_colors)

ax.set_ylabel('Cantidad de puertas')
ax.set_title('Autos agrupados segun cantidad de puertas')


plt.show()

# %%
#Se agrupan los datos por categoria
gf4= dfAutos.groupby(["style"]).count()
#Se extrae el indice y la primera columna con datos
gf4= gf4.iloc[:,:1]
gf4
# Out:
#              symboling
# style
# convertible          8
# hardtop             10
# hatchback           75
# sedan              103
# wagon               26

# %%
names = gf4.index.tolist()
style = gf4["symboling"].tolist()
my_circle= plt.Circle((0,0),0.7,color="white")

plt.pie(style, labels=names, autopct="%1.1f%%",colors= ["#112534","#0e4f64","#0a86a2","#05cde8","#0ffff8"])

p= plt.gcf()

p.gca().add_artist(my_circle)

plt.show()
